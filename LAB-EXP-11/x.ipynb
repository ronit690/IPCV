# %%
import cv2
import numpy as np

# %%
img = cv2.imread(r'D:\IPCV\LAB-EXP-11\images\1.jpg',0)

# %%
edges = cv2.Canny(img,100,200)

# %%
cv2.imwrite(r'D:\IPCV\LAB-EXP-11\images\edges.jpg', edges)
# Out:
# True
