# %%
import cv2
import numpy as np

# %%
img = cv2.imread(r'D:\IPCV\LAB-EXP-11\images\1.jpg',0)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

# %%
gray = np.float32(gray)

# %%
img_float = np.float32(img)
coreners = cv2.cornerHarris(img_float,2,3,0.04)

# %%
print(coreners)
# Out:
# [[ 6.8750000e-01  6.8750000e-01  1.0400001e+00 ... -2.4010000e+01
#   -2.4010000e+01 -2.4010000e+01]
#  [ 6.8750000e-01  6.8750000e-01  1.0400001e+00 ... -2.4010000e+01
#   -2.4010000e+01 -2.4010000e+01]
#  [ 2.2962499e+00  2.2962499e+00  4.8068752e+00 ... -2.2200999e+02
#   -2.2200999e+02 -2.2200999e+02]
#  ...
#  [-9.3877969e+03 -9.3877969e+03 -1.1322762e+04 ...  1.5078005e+04
#    3.3408434e+04  2.1119809e+04]
#  [-6.9800723e+03 -6.9800723e+03 -2.7842820e+04 ...  1.7927931e+03
#    2.1056301e+04  6.4651680e+03]
#  [ 8.5130117e+03  8.5130117e+03  2.3433965e+04 ...  1.9776782e+02
#    5.1912656e+03  2.6824117e+04]]

# %%
cv2.imwrite(r'D:\IPCV\LAB-EXP-12\images\coreners.jpg', coreners)
# Out:
# True
