# %%
import cv2
import numpy as np

# %%
img = cv2.imread(r'D:\IPCV\LAB-EXP-10\images\1.jpg',0)

# %%
mean = np.mean(img)
variance = np.var(img)

# %%
print(mean)
print(variance)
# Out:
# 99.4009736711376
# 3628.7550472387506
